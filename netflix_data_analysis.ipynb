# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Netflix Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.size
# Out:
# 85679

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Show_Id         7787
# Category           2
# Title           7787
# Director        4050
# Cast            6831
# Country          681
# Release_Date    1565
# Rating            14
# Duration         216
# Type             492
# Description     7769
# dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['Brazil', 'Mexico', 'Singapore', 'United States', 'Turkey',
#        'Egypt', 'India', 'Poland, United States', 'Thailand', 'Nigeria',
#        nan, 'Norway, Iceland, United States', 'United Kingdom', 'Japan',
#        'South Korea', 'Italy', 'Canada', 'Indonesia', 'Romania', 'Spain',
#        'Iceland', 'South Africa, Nigeria', 'France',
#        'United States, South Africa', 'Portugal, Spain',
#        'Hong Kong, China, Singapore', 'United States, Germany',
#        'South Africa, China, United States', 'Argentina',
#        'United States, France, Serbia', 'Germany',
#        'Denmark, France, Poland', 'Poland', 'Kenya',
#        'New Zealand, United Kingdom', 'Pakistan', 'Australia',
#        'Australia, United States', 'Mexico, United States',
#        'United States, China', 'China, Hong Kong', 'Taiwan',
#        'United States, United Kingdom', 'France, South Korea, Japan',
#        'United States, Canada', 'United Kingdom, United States',
# ...

# %% [markdown]
# ## removing duplicates from dataset=>

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# so we can see that we have 2 duplicate data row in the dataset

# %%
df.drop_duplicates(inplace= True)

# %%
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# so here we can see that we have now less rows in the data as compare to the previous data row, so its means the duplicated rows are removed

# %% [markdown]
# ##checking null values =>

# %%
df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# here we can see the count of null values in which colunms

# %% [markdown]
# #Q.1="house of card" who is director of this show and whats the show id of it?

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# so we can check their show id and director of this show

# %% [markdown]
# #Q.2=In which year the highest num of movies and show were relaease , show it bar graph ?

# %%
df['date_new']=pd.to_datetime(df['Release_Date'])

# %%
df['date_new'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: date_new, dtype: int64

# %% [markdown]
# here we can see that in 2019 year their was max movies and show was released

# %%
df['date_new'].dt.year.value_counts().plot(kind='bar')

# %% [markdown]
# #Q.3=how many movies and tv shows are in this dataset , show it with bar graph ?

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(df['Category'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #Q.4=show all the movie that were released in year 2000 ?

# %%
df['year']=df['date_new'].dt.year

# %%
df[(df['Category']=='movies') & (df['year']==2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, date_new, year]
# Index: []

# %% [markdown]
# here its showing zero movies were release in year 2000

# %% [markdown]
# #Q.5= shows all the title of tv shows that where released in india ?

# %%
df[(df['Category']=='TV Show') & (df['Country']=='India')] ['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# #Q.6=show top 10 directors who gave highest number of tv shows & movies to netflix ?

# %%
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %%
df['Director'].value_counts().head(10).plot(kind='bar')

# %% [markdown]
# #Q.7=show all the records , where "category is movie and type in comedies" or "country is united kingdom" ?

# %%
df[(df['Category']=='Movie') & (df['Type']=='Comedies') | (df['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# #Q.8= in how many movies/shows,Tom Cruise was cast ?

# %%
df_new=df.dropna()                  #its drop all the null values from data and save its as a new data frame

# %%
df_new[(df_new['Cast']=='Tom Cruise')]  #that filtering giving us zero result because its dont show result where multiple values have as compare to search value
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, date_new, year]
# Index: []

# %%
df_new[df_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description   date_new    year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# #Q.9= what are the different rating defined by netflix ?

# %%
df['Rating'].nunique()
# Out:
# 14

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #Q.10= how many movies got 'tv-14' rating in canada ?

# %%
df[(df['Category']=='Movie') & (df['Rating']=='TV-14') & (df['Country']=='Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %% [markdown]
# #Q.11= How many tv shows got 'R' rating, after year 2018 ?

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   date_new    year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description   date_new    year
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10  2016.0
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
df[(df['Category']=='TV Show') & (df['Rating']=='R') & (df['year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description   date_new    year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# #Q.12=What is the maximum duration of movies/tv shows on netflix ?

# %%
df['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df[['Minute','Unit']]= df['Duration'].str.split(' ', expand = True)

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   date_new    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minute     Unit
# 0      4  Seasons
# 1     93      min

# %%
df['Minute'].max()
# Out:
# '99'

# %% [markdown]
# #Q.13= Which individual country has the highest no of TV Shows ?

# %%
df_tvshows = df[df['Category']=='TV Shows']

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          Description   date_new    year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minute     Unit
# 0      4  Seasons
# 1     93      min

# %%
df_tvshows.Country.value_counts()
# Out:
# Series([], Name: Country, dtype: int64)

# %% [markdown]
# #Q.14= How can we sort the dataset by year ?

# %%
df.sort_values(by = 'year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
df.sort_values(by = 'year', ascending=False).head(5)
# Out:
#      Show_Id Category             Title                 Director  \
# 5564   s5564    Movie   Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie         Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show      Bling Empire                      NaN
# 5955   s5955    Movie  Taare Zameen Par               Aamir Khan
# 366     s367    Movie         Al acecho      Francisco D'Eufemia
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
# 5955  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...
# 366   Rodrigo de la Serna, Belen Blanco, Walter Jako...
#
#                                                 Country      Release_Date  \
# 5564  United States, Germany, United Kingdom, Australia   January 1, 2021
# 5919                                      United States   January 1, 2021
# ...
